# %%
# %%pyspark
# df = spark.read.load('abfss://fsyoanndp@datalakeyoanndp.dfs.core.windows.net/products.csv', format='csv'
# , header=True
# )
# display(df.limit(10))
# Out:
# StatementMeta(spark, 0, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, fb4f1c99-eb61-4ea9-af51-f2f58888148a)

# %%
df_counts = df.groupby(df.Category).count()
display(df_counts)
# Out:
# StatementMeta(spark, 0, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, afe3ae1a-ba4a-4fc4-9a7e-3db0cf0d1f94)
